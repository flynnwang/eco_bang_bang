# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import sys

sys.path.insert(0, "/Users/flynnwang/repo/flynn/eco_bang_bang/agents/rule_0202")

# %%
sys.path.insert(0, "/Users/flynnwang/repo/flynn/eco_bang_bang/agents")

# %%
# from ebb.env.const import *

# %%
import torch

from ecobangbang.env.luxenv import get_ob_sapce, LuxS3Env
from ecobangbang.model import _create_model, RewardSpec

reward_spec = RewardSpec(
        reward_min=-5,
        reward_max=+5,
        zero_sum=False,
    )

reward_shaping_params = dict(  new_observed_down_tri=0.0001,
  match_observed=0,
  match_win=1,
  use_hidden_relic_estimator=True,
  energy_cost_change=0.001,                             
)

obs_space_kwargs = {
    'use_energy_cost_map': True,
    'use_single_player': False,
}
env = LuxS3Env(reward_schema='match_explore_win_loss',
               reward_shaping_params=reward_shaping_params,
              obs_space_kwargs=obs_space_kwargs)

obs, reward, done, info = env.reset()

# %%
from ecobangbang.agent import Agent

from rule_v3_4a0760b.ecobangbang.agent import Agent as Agent2

# %% [markdown]
# # Feature Plots

# %%
def plot_imgs(images):
    grid_size = 3
    fig, axes = plt.subplots(grid_size + 1, grid_size, figsize=(10, 10))
    
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            name, img = images[i]
            img = img.T
            ax.imshow(img, cmap='viridis')  # Display image (grayscale here)
            ax.set_title(name, fontsize=8)
            ax.axis('off')  # Turn off the axes
            ax.set_xticks(np.arange(-0.5, img.shape[1], 1))  # Position gridlines at the edges of the pixels
            ax.set_yticks(np.arange(-0.5, img.shape[0], 1))  # Position gridlines at the edges of the pixels
            # Set gridlines to be visible
            ax.grid(which='both', color='black', linestyle='-', linewidth=.5)
        else:
            ax.axis('off')  # Turn off the axes for empty slots
    
    plt.tight_layout()
    plt.show()

# %%
import ecobangbang

ecobangbang
# Out:
# <module 'ecobangbang' from '/Users/flynnwang/repo/flynn/eco_bang_bang/agents/rule_0202/ecobangbang/__init__.py'>

# %%
from ecobangbang.env.luxenv import LuxS3Env
from ecobangbang.env.const import *


env = LuxS3Env(reward_schema='match_explore_win_loss',
               reward_shaping_params=reward_shaping_params,
              obs_space_kwargs=obs_space_kwargs)
obs, reward, done, info = env.reset(seed=1544283652)

def act(a, ob):
    player_id = a.player
    step = ob['steps']
    actions = a.act(step, ob)
    return actions

env_cfg = env.mms[0].env_cfg
# a0 = Agent2('player_0', env_cfg)
a0 = Agent('player_0', env_cfg)
a1 = Agent('player_1', env_cfg)

# %%
for i in range(100):
    action0 = env.agent_action_do_model_action(act(a0, env.mms[0].past_obs[0]), env.mms[0])
    action1 = env.agent_action_do_model_action(act(a1, env.mms[1].past_obs[0]), env.mms[1])
    player_actions = [{UNITS_ACTION: action0}, {UNITS_ACTION: action1}]
    obs, reward, done, info = env.step(player_actions)
# Out:
# ============ game step 1 ==========
#  +++ step=0 to-exp-cell-num=576 exp_score=2.9948006932409013 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
# ============ game step 1 ==========
#  +++ step=0 to-exp-cell-num=576 exp_score=2.9948006932409013 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
# step=1 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# [debug][step=1] comm_visible.sum() = 0
# ***** --> found energy node at [15  2]
# step=0 (after update), energy field found=True, node=[15  2], candidates=[array([15,  2])]
# --> using energy node at [15  2]
# [debug][step=1] comm_visible.sum() = 0
# xxxxxxxxxxx  1
# ***** --> found energy node at [15  2]
# step=0 (after update), energy field found=True, node=[15  2], candidates=[array([15,  2])]
# --> using energy node at [15  2]
# ============ game step 1 ==========
# [debug][step=1] comm_visible.sum() = 0
# xxxxxxxxxxx  1
# ***** --> found energy node at [15  2]
# step=0 (after update), energy field found=True, node=[15  2], candidates=[array([15,  2])]
# --> using energy node at [15  2]
#  +++ step=1 to-exp-cell-num=526 exp_score=3.2789373814041745 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[0 0] assgined to cell=(0, 5), wts={'explore_wt': np.float64(3.2789373814041745), 'fuel_wt': np.float64(0.7469088762520901), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.639344262295082), 'wt': np.float64(2.272585258851523), 'mdist': np.float64(1.7715610000000008)}
# pid=[player_0] game_step=1 sending unit=0 pos=[0 0] to cell=(0, 5)
# ============ game step 1 ==========
# [debug][step=1] comm_visible.sum() = 0
# xxxxxxxxxxx  1
# ***** --> found energy node at [15  2]
# step=0 (after update), energy field found=True, node=[15  2], candidates=[array([15,  2])]
# --> using energy node at [15  2]
#  +++ step=1 to-exp-cell-num=526 exp_score=3.2789373814041745 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[23 23] assgined to cell=(18, 23), wts={'explore_wt': np.float64(3.2789373814041745), 'fuel_wt': np.float64(0.7469088762520901), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.639344262295082), 'wt': np.float64(2.272585258851523), 'mdist': np.float64(1.7715610000000008)}
# pid=[player_1] game_step=1 sending unit=0 pos=[23 23] to cell=(18, 23)
# [debug][step=2] comm_visible.sum() = 25
# xxxxxxxxxxx  1
# step=2 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# ***** --> found energy node at [17  4]
# ----------small reset energy node positions, found? = True
# energy field changed at step = 1
# step=1 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=2] comm_visible.sum() = 25
# ***** --> found energy node at [17  4]
# xxxxxxxxxxx  2
# xxxxxxxxxxx  2
# ----------small reset energy node positions, found? = True
# energy field changed at step = 1
# step=1 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 2 ==========
# [debug][step=2] comm_visible.sum() = 25
# ***** --> found energy node at [17  4]
# ----------small reset energy node positions, found? = True
# energy field changed at step = 1
# step=1 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=2 to-exp-cell-num=516 exp_score=3.3423597678916828 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[0 1] assgined to cell=(2, 6), wts={'explore_wt': np.float64(3.3423597678916828), 'fuel_wt': np.float64(0.541919554856682), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.596774193548387), 'wt': np.float64(1.8121449708581758), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_0] game_step=2 sending unit=0 pos=[0 1] to cell=(2, 6)
# ============ game step 2 ==========
# [debug][step=2] comm_visible.sum() = 25
# xxxxxxxxxxx  2
# xxxxxxxxxxx  2
# step=3 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  3
# ***** --> found energy node at [17  4]
# ----------small reset energy node positions, found? = True
# energy field changed at step = 1
# step=1 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=2 to-exp-cell-num=516 exp_score=3.3423597678916828 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[22 23] assgined to cell=(17, 21), wts={'explore_wt': np.float64(3.3423597678916828), 'fuel_wt': np.float64(0.541919554856682), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.596774193548387), 'wt': np.float64(1.8121449708581758), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_1] game_step=2 sending unit=0 pos=[22 23] to cell=(17, 21)
# [debug][step=3] comm_visible.sum() = 30
# step=2 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=3] comm_visible.sum() = 30
# step=2 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 3 ==========
# [debug][step=3] comm_visible.sum() = 30
# step=2 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=3 to-exp-cell-num=504 exp_score=3.4217821782178217 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[1 1] assgined to cell=(2, 6), wts={'explore_wt': np.float64(3.4217821782178217), 'fuel_wt': np.float64(0.5936960972508439), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5714285714285714), 'wt': np.float64(2.060675275635783), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_0] game_step=3 sending unit=0 pos=[1 1] to cell=(2, 6)
# ============ game step 3 ==========
# [debug][step=3] comm_visible.sum() = 30
# step=2 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=3 to-exp-cell-num=504 exp_score=3.4217821782178217 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[22 22] assgined to cell=(17, 21), wts={'explore_wt': np.float64(3.4217821782178217), 'fuel_wt': np.float64(0.5936960972508439), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5714285714285714), 'wt': np.float64(2.060675275635783), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_1] game_step=3 sending unit=0 pos=[22 22] to cell=(17, 21)
# [debug][step=4] comm_visible.sum() = 36
# step=3 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=4] comm_visible.sum() = 36
# step=3 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 4 ==========
# [debug][step=4] comm_visible.sum() = 36
# step=3 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=4 to-exp-cell-num=492 exp_score=3.5050709939148073 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[1 2] assgined to cell=(2, 7), wts={'explore_wt': np.float64(3.5050709939148073), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.546875), 'wt': np.float64(2.2426685396994537), 'mdist': np.float64(1.9487171000000012)}
#  unit[1]=[0 0] assgined to cell=(6, 0), wts={'explore_wt': np.float64(3.5050709939148073), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5625), 'wt': np.float64(1.7987556355023544), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_0] game_step=4 sending unit=0 pos=[1 2] to cell=(2, 7)
# pid=[player_0] game_step=4 sending unit=1 pos=[0 0] to cell=(6, 0)
# ============ game step 4 ==========
# [debug][step=4] comm_visible.sum() = 36
# step=3 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=4 to-exp-cell-num=492 exp_score=3.5050709939148073 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[21 22] assgined to cell=(16, 21), wts={'explore_wt': np.float64(3.5050709939148073), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.546875), 'wt': np.float64(2.2426685396994537), 'mdist': np.float64(1.9487171000000012)}
#  unit[1]=[23 23] assgined to cell=(23, 17), wts={'explore_wt': np.float64(3.5050709939148073), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5625), 'wt': np.float64(1.7987556355023544), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_1] game_step=4 sending unit=0 pos=[21 22] to cell=(16, 21)
# pid=[player_1] game_step=4 sending unit=1 pos=[23 23] to cell=(23, 17)
# [debug][step=5] comm_visible.sum() = 42
# step=4 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=5] comm_visible.sum() = 42
# step=4 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 5 ==========
# [debug][step=5] comm_visible.sum() = 42
# step=4 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=5 to-exp-cell-num=478 exp_score=3.607515657620042 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[2 2] assgined to cell=(2, 7), wts={'explore_wt': np.float64(3.607515657620042), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5384615384615385), 'wt': np.float64(2.5247527356041304), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[0 1] assgined to cell=(1, 7), wts={'explore_wt': np.float64(3.607515657620042), 'fuel_wt': np.float64(0.23574607655586352), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.523076923076923), 'wt': np.float64(1.7930099630707172), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_0] game_step=5 sending unit=0 pos=[2 2] to cell=(2, 7)
# pid=[player_0] game_step=5 sending unit=1 pos=[0 1] to cell=(1, 7)
# ============ game step 5 ==========
# [debug][step=5] comm_visible.sum() = 42
# step=4 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=5 to-exp-cell-num=478 exp_score=3.607515657620042 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[21 21] assgined to cell=(16, 21), wts={'explore_wt': np.float64(3.607515657620042), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5384615384615385), 'wt': np.float64(2.5247527356041304), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[22 23] assgined to cell=(16, 22), wts={'explore_wt': np.float64(3.607515657620042), 'fuel_wt': np.float64(0.23574607655586352), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.523076923076923), 'wt': np.float64(1.7930099630707172), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_1] game_step=5 sending unit=0 pos=[21 21] to cell=(16, 21)
# pid=[player_1] game_step=5 sending unit=1 pos=[22 23] to cell=(16, 22)
# [debug][step=6] comm_visible.sum() = 49
# step=5 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=6] comm_visible.sum() = 49
# step=5 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 6 ==========
# [debug][step=6] comm_visible.sum() = 49
# step=5 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=6 to-exp-cell-num=464 exp_score=3.7161290322580647 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[2 3] assgined to cell=(2, 8), wts={'explore_wt': np.float64(3.7161290322580647), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5303030303030303), 'wt': np.float64(2.5860621540424584), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[1 1] assgined to cell=(7, 1), wts={'explore_wt': np.float64(3.7161290322580647), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5), 'wt': np.float64(1.9070617812960446), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_0] game_step=6 sending unit=0 pos=[2 3] to cell=(2, 8)
# pid=[player_0] game_step=6 sending unit=1 pos=[1 1] to cell=(7, 1)
# ============ game step 6 ==========
# [debug][step=6] comm_visible.sum() = 49
# step=5 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=6 to-exp-cell-num=464 exp_score=3.7161290322580647 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[20 21] assgined to cell=(15, 21), wts={'explore_wt': np.float64(3.7161290322580647), 'fuel_wt': np.float64(0.8650606673195492), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5303030303030303), 'wt': np.float64(2.5860621540424584), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[22 22] assgined to cell=(22, 16), wts={'explore_wt': np.float64(3.7161290322580647), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5), 'wt': np.float64(1.9070617812960446), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_1] game_step=6 sending unit=0 pos=[20 21] to cell=(15, 21)
# pid=[player_1] game_step=6 sending unit=1 pos=[22 22] to cell=(22, 16)
# [debug][step=7] comm_visible.sum() = 56
# step=6 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=7] comm_visible.sum() = 56
# step=6 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 7 ==========
# [debug][step=7] comm_visible.sum() = 56
# step=6 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=7 to-exp-cell-num=450 exp_score=3.8314855875831486 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[2 4] assgined to cell=(2, 9), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.7915947963344586), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.537313432835821), 'wt': np.float64(2.6097083532644967), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[1 2] assgined to cell=(7, 2), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4776119402985075), 'wt': np.float64(1.966257934152241), 'mdist': np.float64(1.9487171000000012)}
#  unit[2]=[0 0] assgined to cell=(7, 0), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.492537313432836), 'wt': np.float64(1.7875163037747643), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_0] game_step=7 sending unit=0 pos=[2 4] to cell=(2, 9)
# pid=[player_0] game_step=7 sending unit=1 pos=[1 2] to cell=(7, 2)
# pid=[player_0] game_step=7 sending unit=2 pos=[0 0] to cell=(7, 0)
# ============ game step 7 ==========
# [debug][step=7] comm_visible.sum() = 56
# step=6 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=7 to-exp-cell-num=450 exp_score=3.8314855875831486 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
# xxxxxxxxxxx  3
# xxxxxxxxxxx  3
# xxxxxxxxxxx  3
# step=4 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  4
# xxxxxxxxxxx  4
# xxxxxxxxxxx  4
# xxxxxxxxxxx  4
# step=5 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  5
# xxxxxxxxxxx  5
# xxxxxxxxxxx  5
# xxxxxxxxxxx  5
# step=6 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  6
# xxxxxxxxxxx  6
# xxxxxxxxxxx  6
# xxxxxxxxxxx  6
# step=7 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  7
# xxxxxxxxxxx  7
# xxxxxxxxxxx  7
# xxxxxxxxxxx  7
# step=8 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  8
# xxxxxxxxxxx  8
# xxxxxxxxxxx  8
# xxxxxxxxxxx  8
#  unit[0]=[19 21] assgined to cell=(14, 21), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.7915947963344586), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.537313432835821), 'wt': np.float64(2.6097083532644967), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[21 22] assgined to cell=(21, 16), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4776119402985075), 'wt': np.float64(1.966257934152241), 'mdist': np.float64(1.9487171000000012)}
#  unit[2]=[23 23] assgined to cell=(23, 16), wts={'explore_wt': np.float64(3.8314855875831486), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.492537313432836), 'wt': np.float64(1.7875163037747643), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_1] game_step=7 sending unit=0 pos=[19 21] to cell=(14, 21)
# pid=[player_1] game_step=7 sending unit=1 pos=[21 22] to cell=(21, 16)
# pid=[player_1] game_step=7 sending unit=2 pos=[23 23] to cell=(23, 16)
# [debug][step=8] comm_visible.sum() = 63
# step=7 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=8] comm_visible.sum() = 63
# step=7 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 8 ==========
# [debug][step=8] comm_visible.sum() = 63
# step=7 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=8 to-exp-cell-num=436 exp_score=3.954233409610984 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[2 5] assgined to cell=(2, 10), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.7225594064755759), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5441176470588236), 'wt': np.float64(2.6400276209436524), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[2 2] assgined to cell=(7, 2), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4705882352941178), 'wt': np.float64(2.2321616730730596), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[0 1] assgined to cell=(7, 1), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4558823529411764), 'wt': np.float64(1.8447790686554206), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_0] game_step=8 sending unit=0 pos=[2 5] to cell=(2, 10)
# pid=[player_0] game_step=8 sending unit=1 pos=[2 2] to cell=(7, 2)
# pid=[player_0] game_step=8 sending unit=2 pos=[0 1] to cell=(7, 1)
# ============ game step 8 ==========
# [debug][step=8] comm_visible.sum() = 63
# step=7 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=8 to-exp-cell-num=436 exp_score=3.954233409610984 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[18 21] assgined to cell=(13, 21), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.7225594064755759), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5441176470588236), 'wt': np.float64(2.6400276209436524), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[21 21] assgined to cell=(21, 16), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4705882352941178), 'wt': np.float64(2.2321616730730596), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[22 23] assgined to cell=(22, 16), wts={'explore_wt': np.float64(3.954233409610984), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4558823529411764), 'wt': np.float64(1.8447790686554206), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_1] game_step=8 sending unit=0 pos=[18 21] to cell=(13, 21)
# pid=[player_1] game_step=8 sending unit=1 pos=[21 21] to cell=(21, 16)
# pid=[player_1] game_step=8 sending unit=2 pos=[22 23] to cell=(22, 16)
# [debug][step=9] comm_visible.sum() = 70
# step=8 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=9] comm_visible.sum() = 70
# step=8 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 9 ==========
# [debug][step=9] comm_visible.sum() = 70
# step=8 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=9 to-exp-cell-num=422 exp_score=4.085106382978723 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[2 6] assgined to cell=(7, 6), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.44814532575125404), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.565217391304348), 'wt': np.float64(2.559002407949811), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[2 3] assgined to cell=(7, 3), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.27803730045319414), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.463768115942029), 'wt': np.float64(2.462980862376128), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[1 1] assgined to cell=(7, 1), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.434782608695652), 'wt': np.float64(2.096405504261609), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_0] game_step=9 sending unit=0 pos=[2 6] to cell=(7, 6)
# pid=[player_0] game_step=9 sending unit=1 pos=[2 3] to cell=(7, 3)
# pid=[player_0] game_step=9 sending unit=2 pos=[1 1] to cell=(7, 1)
# ============ game step 9 ==========
# [debug][step=9] comm_visible.sum() = 70
# step=8 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=9 to-exp-cell-num=422 exp_score=4.085106382978723 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[17 21] assgined to cell=(17, 16), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.44814532575125404), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.565217391304348), 'wt': np.float64(2.559002407949811), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[20 21] assgined to cell=(20, 16), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.27803730045319414), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.463768115942029), 'wt': np.float64(2.462980862376128), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[22 22] assgined to cell=(22, 16), wts={'explore_wt': np.float64(4.085106382978723), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.434782608695652), 'wt': np.float64(2.096405504261609), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_1] game_step=9 sending unit=0 pos=[17 21] to cell=(17, 16)
# pid=[player_1] game_step=9 sending unit=1 pos=[20 21] to cell=(20, 16)
# pid=[player_1] game_step=9 sending unit=2 pos=[22 22] to cell=(22, 16)
# [debug][step=10] comm_visible.sum() = 77
# step=9 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=10] comm_visible.sum() = 77
# step=9 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 10 ==========
# [debug][step=10] comm_visible.sum() = 77
# step=9 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=10 to-exp-cell-num=400 exp_score=4.309226932668329 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[3 6] assgined to cell=(3, 11), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.9868467394629294), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.542857142857143), 'wt': np.float64(2.9895955195622714), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[3 3] assgined to cell=(8, 3), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4428571428571428), 'wt': np.float64(2.432546262176875), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[1 2] assgined to cell=(8, 2), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4142857142857144), 'wt': np.float64(2.0103861670883263), 'mdist': np.float64(2.1435888100000016)}
#  unit[3]=[0 0] assgined to cell=(8, 0), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(-0.32465246735834974), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4285714285714286), 'wt': np.float64(1.6899485409657784), 'mdist': np.float64(2.357947691000002)}
# pid=[player_0] game_step=10 sending unit=0 pos=[3 6] to cell=(3, 11)
# pid=[player_0] game_step=10 sending unit=1 pos=[3 3] to cell=(8, 3)
# pid=[player_0] game_step=10 sending unit=2 pos=[1 2] to cell=(8, 2)
# pid=[player_0] game_step=10 sending unit=3 pos=[0 0] to cell=(8, 0)
# ============ game step 10 ==========
# [debug][step=10] comm_visible.sum() = 77
# step=9 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=10 to-exp-cell-num=400 exp_score=4.309226932668329 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[17 20] assgined to cell=(12, 20), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.9868467394629294), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.542857142857143), 'wt': np.float64(2.9895955195622714), 'mdist': np.float64(1.7715610000000008)}
#  unit[1]=[20 20] assgined to cell=(20, 15), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4428571428571428), 'wt': np.float64(2.432546262176875), 'mdist': np.float64(1.7715610000000008)}
#  unit[2]=[21 22] assgined to cell=(21, 15), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4142857142857144), 'wt': np.float64(2.0103861670883263), 'mdist': np.float64(2.1435888100000016)}
#  unit[3]=[23 23] assgined to cell=(23, 15), wts={'explore_wt': np.float64(4.309226932668329), 'fuel_wt': np.float64(-0.32465246735834974), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4285714285714286), 'wt': np.float64(1.6899485409657784), 'mdist': np.float64(2.357947691000002)}
# pid=[player_1] game_step=10 sending unit=0 pos=[17 20] to cell=(12, 20)
# pid=[player_1] game_step=10 sending unit=1 pos=[20 20] to cell=(20, 15)
# pid=[player_1] game_step=10 sending unit=2 pos=[21 22] to cell=(21, 15)
# pid=[player_1] game_step=10 sending unit=3 pos=[23 23] to cell=(23, 15)
# [debug][step=11] comm_visible.sum() = 88
# step=10 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=11] comm_visible.sum() = 88
# step=10 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 11 ==========
# [debug][step=11] comm_visible.sum() = 88
# step=10 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=11 to-exp-cell-num=372 exp_score=4.632707774798928 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[3 7] assgined to cell=(3, 11), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(0.9868467394629294), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5352112676056338), 'wt': np.float64(3.4894012239985193), 'mdist': np.float64(1.6105100000000006)}
#  unit[1]=[4 3] assgined to cell=(4, 13), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(2.627177691959797), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3943661971830985), 'wt': np.float64(2.5446455670325525), 'mdist': np.float64(2.8531167061100025)}
#  unit[2]=[2 2] assgined to cell=(3, 12), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(1.7475030009987824), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.408450704225352), 'wt': np.float64(2.033031776656853), 'mdist': np.float64(3.138428376721003)}
#  unit[3]=[0 1] assgined to cell=(8, 1), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3943661971830985), 'wt': np.float64(1.964820333907918), 'mdist': np.float64(2.357947691000002)}
# pid=[player_0] game_step=11 sending unit=0 pos=[3 7] to cell=(3, 11)
# pid=[player_0] game_step=11 sending unit=1 pos=[4 3] to cell=(4, 13)
# pid=[player_0] game_step=11 sending unit=2 pos=[2 2] to cell=(3, 12)
# pid=[player_0] game_step=11 sending unit=3 pos=[0 1] to cell=(8, 1)
# ============ game step 11 ==========
# [debug][step=11] comm_visible.sum() = 88
# step=10 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=11 to-exp-cell-num=372 exp_score=4.632707774798928 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
# step=9 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  9
# xxxxxxxxxxx  9
# xxxxxxxxxxx  9
# xxxxxxxxxxx  9
# step=10 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  10
# xxxxxxxxxxx  10
# xxxxxxxxxxx  10
# xxxxxxxxxxx  10
# step=11 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  11
# xxxxxxxxxxx  11
# xxxxxxxxxxx  11
# xxxxxxxxxxx  11
# step=12 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  12
# xxxxxxxxxxx  12
# xxxxxxxxxxx  12
#  unit[0]=[16 20] assgined to cell=(12, 20), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(0.9868467394629294), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5352112676056338), 'wt': np.float64(3.4894012239985193), 'mdist': np.float64(1.6105100000000006)}
#  unit[1]=[20 19] assgined to cell=(10, 19), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(2.627177691959797), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3943661971830985), 'wt': np.float64(2.5446455670325525), 'mdist': np.float64(2.8531167061100025)}
#  unit[2]=[21 21] assgined to cell=(11, 20), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(1.7475030009987824), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.408450704225352), 'wt': np.float64(2.033031776656853), 'mdist': np.float64(3.138428376721003)}
#  unit[3]=[22 23] assgined to cell=(22, 15), wts={'explore_wt': np.float64(4.632707774798928), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3943661971830985), 'wt': np.float64(1.964820333907918), 'mdist': np.float64(2.357947691000002)}
# pid=[player_1] game_step=11 sending unit=0 pos=[16 20] to cell=(12, 20)
# pid=[player_1] game_step=11 sending unit=1 pos=[20 19] to cell=(10, 19)
# pid=[player_1] game_step=11 sending unit=2 pos=[21 21] to cell=(11, 20)
# pid=[player_1] game_step=11 sending unit=3 pos=[22 23] to cell=(22, 15)
# [debug][step=12] comm_visible.sum() = 95
# step=11 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=12] comm_visible.sum() = 95
# step=11 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 12 ==========
# [debug][step=12] comm_visible.sum() = 95
# step=11 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=12 to-exp-cell-num=362 exp_score=4.760330578512397 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[3 8] assgined to cell=(3, 11), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(0.8962906515025081), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5416666666666667), 'wt': np.float64(3.863648412003896), 'mdist': np.float64(1.4641000000000004)}
#  unit[1]=[3 3] assgined to cell=(3, 12), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(2.0101069154732745), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.375), 'wt': np.float64(2.6103967423082692), 'mdist': np.float64(2.5937424601000023)}
#  unit[2]=[2 3] assgined to cell=(4, 13), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(2.4465042013982954), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4027777777777777), 'wt': np.float64(2.087663326387619), 'mdist': np.float64(3.452271214393104)}
#  unit[3]=[1 1] assgined to cell=(8, 1), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.375), 'wt': np.float64(2.2208293471141016), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_0] game_step=12 sending unit=0 pos=[3 8] to cell=(3, 11)
# pid=[player_0] game_step=12 sending unit=1 pos=[3 3] to cell=(3, 12)
# pid=[player_0] game_step=12 sending unit=2 pos=[2 3] to cell=(4, 13)
# pid=[player_0] game_step=12 sending unit=3 pos=[1 1] to cell=(8, 1)
# ============ game step 12 ==========
# [debug][step=12] comm_visible.sum() = 95
# step=11 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=12 to-exp-cell-num=362 exp_score=4.760330578512397 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[15 20] assgined to cell=(12, 20), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(0.8962906515025081), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5416666666666667), 'wt': np.float64(3.863648412003896), 'mdist': np.float64(1.4641000000000004)}
#  unit[1]=[20 20] assgined to cell=(11, 20), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(2.0101069154732745), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.375), 'wt': np.float64(2.6103967423082692), 'mdist': np.float64(2.5937424601000023)}
#  unit[2]=[20 21] assgined to cell=(10, 19), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(2.4465042013982954), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4027777777777777), 'wt': np.float64(2.087663326387619), 'mdist': np.float64(3.452271214393104)}
#  unit[3]=[22 22] assgined to cell=(22, 15), wts={'explore_wt': np.float64(4.760330578512397), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.375), 'wt': np.float64(2.2208293471141016), 'mdist': np.float64(2.1435888100000016)}
# pid=[player_1] game_step=12 sending unit=0 pos=[15 20] to cell=(12, 20)
# pid=[player_1] game_step=12 sending unit=1 pos=[20 20] to cell=(11, 20)
# pid=[player_1] game_step=12 sending unit=2 pos=[20 21] to cell=(10, 19)
# pid=[player_1] game_step=12 sending unit=3 pos=[22 22] to cell=(22, 15)
# [debug][step=13] comm_visible.sum() = 100
# step=12 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=13] comm_visible.sum() = 100
# step=12 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 13 ==========
# [debug][step=13] comm_visible.sum() = 100
# step=12 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=13 to-exp-cell-num=348 exp_score=4.951289398280802 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[3 9] assgined to cell=(3, 12), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.611517266734503), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5616438356164384), 'wt': np.float64(3.799571801799948), 'mdist': np.float64(1.4641000000000004)}
#  unit[1]=[3 4] assgined to cell=(4, 13), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(3.006901507475174), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.356164383561644), 'wt': np.float64(2.7893973633757647), 'mdist': np.float64(2.8531167061100025)}
#  unit[2]=[2 4] assgined to cell=(9, 4), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4109589041095891), 'wt': np.float64(2.309913045852203), 'mdist': np.float64(2.1435888100000016)}
#  unit[3]=[1 2] assgined to cell=(8, 1), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.356164383561644), 'wt': np.float64(2.0999300416838205), 'mdist': np.float64(2.357947691000002)}
#  unit[4]=[0 0] assgined to cell=(9, 0), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(-0.40202138309465485), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.36986301369863), 'wt': np.float64(1.7540397550714226), 'mdist': np.float64(2.5937424601000023)}
# pid=[player_0] game_step=13 sending unit=0 pos=[3 9] to cell=(3, 12)
# pid=[player_0] game_step=13 sending unit=1 pos=[3 4] to cell=(4, 13)
# pid=[player_0] game_step=13 sending unit=2 pos=[2 4] to cell=(9, 4)
# pid=[player_0] game_step=13 sending unit=3 pos=[1 2] to cell=(8, 1)
# pid=[player_0] game_step=13 sending unit=4 pos=[0 0] to cell=(9, 0)
# ============ game step 13 ==========
# [debug][step=13] comm_visible.sum() = 100
# step=12 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=13 to-exp-cell-num=348 exp_score=4.951289398280802 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[14 20] assgined to cell=(11, 20), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.611517266734503), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5616438356164384), 'wt': np.float64(3.799571801799948), 'mdist': np.float64(1.4641000000000004)}
#  unit[1]=[19 20] assgined to cell=(10, 19), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(3.006901507475174), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.356164383561644), 'wt': np.float64(2.7893973633757647), 'mdist': np.float64(2.8531167061100025)}
#  unit[2]=[19 21] assgined to cell=(19, 14), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.4109589041095891), 'wt': np.float64(2.309913045852203), 'mdist': np.float64(2.1435888100000016)}
#  unit[3]=[21 22] assgined to cell=(22, 15), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.356164383561644), 'wt': np.float64(2.0999300416838205), 'mdist': np.float64(2.357947691000002)}
#  unit[4]=[23 23] assgined to cell=(23, 14), wts={'explore_wt': np.float64(4.951289398280802), 'fuel_wt': np.float64(-0.40202138309465485), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.36986301369863), 'wt': np.float64(1.7540397550714226), 'mdist': np.float64(2.5937424601000023)}
# pid=[player_1] game_step=13 sending unit=0 pos=[14 20] to cell=(11, 20)
# pid=[player_1] game_step=13 sending unit=1 pos=[19 20] to cell=(10, 19)
# pid=[player_1] game_step=13 sending unit=2 pos=[19 21] to cell=(19, 14)
# pid=[player_1] game_step=13 sending unit=3 pos=[21 22] to cell=(22, 15)
# pid=[player_1] game_step=13 sending unit=4 pos=[23 23] to cell=(23, 14)
# [debug][step=14] comm_visible.sum() = 107
# step=13 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# [debug][step=14] comm_visible.sum() = 107
# step=13 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
# ============ game step 14 ==========
# [debug][step=14] comm_visible.sum() = 107
# step=13 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=14 to-exp-cell-num=332 exp_score=5.1891891891891895 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
#  unit[0]=[ 3 10] assgined to cell=(3, 13), wts={'explore_wt': np.float64(5.1891891891891895), 'fuel_wt': np.float64(0.23867852615468305), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.6081081081081081), 'wt': np.float64(3.7074066835215294), 'mdist': np.float64(1.4641000000000004)}
#  unit[1]=[3 5] assgined to cell=(4, 13), wts={'explore_wt': np.float64(5.1891891891891895), 'fuel_wt': np.float64(3.2048335324012998), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.337837837837838), 'wt': np.float64(3.236359131628225), 'mdist': np.float64(2.5937424601000023)}
#  unit[2]=[3 4] assgined to cell=(9, 4), wts={'explore_wt': np.float64(5.1891891891891895), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3918918918918919), 'wt': np.float64(2.66297455946745), 'mdist': np.float64(1.9487171000000012)}
#  unit[3]=[2 2] assgined to cell=(8, 1), wts={'explore_wt': np.float64(5.1891891891891895), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.3513513513513513), 'wt': np.float64(2.420895054061318), 'mdist': np.float64(2.1435888100000016)}
#  unit[4]=[0 1] assgined to cell=(9, 1), wts={'explore_wt': np.float64(5.1891891891891895), 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.337837837837838), 'wt': np.float64(2.0007570694721633), 'mdist': np.float64(2.5937424601000023)}
# pid=[player_0] game_step=14 sending unit=0 pos=[ 3 10] to cell=(3, 13)
# pid=[player_0] game_step=14 sending unit=1 pos=[3 5] to cell=(4, 13)
# pid=[player_0] game_step=14 sending unit=2 pos=[3 4] to cell=(9, 4)
# pid=[player_0] game_step=14 sending unit=3 pos=[2 2] to cell=(8, 1)
# pid=[player_0] game_step=14 sending unit=4 pos=[0 1] to cell=(9, 1)
# ============ game step 14 ==========
# [debug][step=14] comm_visible.sum() = 107
# step=13 (after update), energy field found=True, node=[17  4], candidates=[array([17,  4])]
# --> using energy node at [17  4]
#  +++ step=14 to-exp-cell-num=332 exp_score=5.1891891891891895 has_found_relic=False, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=0
# xxxxxxxxxxx  12
# step=13 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  13
# xxxxxxxxxxx  13
# xxxxxxxxxxx  13
# xxxxxxxxxxx  13
# step=14 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  14
# xxxxxxxxxxx  14
# xxxxxxxxxxx  14
# xxxxxxxxxxx  14
# step=15 final_state.energy_nodes=[[17  4]
#  [12  5]
#  [14  1]
#  [19  6]
#  [18 11]
#  [22  9]], final_state.energy_nodes_mask=[ True False  True  True False  True]
# xxxxxxxxxxx  15
# xxxxxxxxxxx  15
# xxxxxxxxxxx  15
# ...
#  unit[7]=[18 14] assgined to cell=(17, 14), wts={'explore_wt': 0, 'fuel_wt': np.float64(4.001244395405598), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.3), 'energy_ratio': np.float64(1.4666666666666666), 'wt': np.float64(6.034186277194707), 'mdist': np.float64(1.2100000000000002)}
#  unit[8]=[22 10] assgined to cell=(17, 13), wts={'explore_wt': 0, 'fuel_wt': np.float64(3.778815947952303), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.4499999999999997), 'energy_ratio': np.float64(1.5333333333333334), 'wt': np.float64(3.065823627179606), 'mdist': np.float64(2.357947691000002)}
#  unit[9]=[22 12] assgined to cell=(22, 12), wts={'explore_wt': 0, 'fuel_wt': np.float64(-0.5460744266397094), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(1.0705555555555555), 'energy_ratio': np.float64(1.3666666666666667), 'wt': np.float64(27.7496282990144), 'mdist': np.float64(1.1)}
#  unit[10]=[15 18] assgined to cell=(15, 18), wts={'explore_wt': 0, 'fuel_wt': np.float64(3.1529415795759843), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.7333333333333334), 'wt': np.float64(2.8664105268872584), 'mdist': np.float64(1.1)}
#  unit[11]=[21  9] assgined to cell=(5, 8), wts={'explore_wt': 0, 'fuel_wt': np.float64(7.697372282885775), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.675), 'energy_ratio': np.float64(1.6333333333333333), 'wt': np.float64(2.0455211171969165), 'mdist': np.float64(5.55991731349224)}
#  unit[12]=[21 13] assgined to cell=(21, 13), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.5021874911181828), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(2.1666666666666665), 'wt': np.float64(27.72936135556198), 'mdist': np.float64(1.1)}
#  unit[13]=[21 14] assgined to cell=(16, 14), wts={'explore_wt': 0, 'fuel_wt': np.float64(2.330751575913456), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.8249999999999997), 'energy_ratio': np.float64(1.7), 'wt': np.float64(3.474861284490601), 'mdist': np.float64(1.7715610000000008)}
#  unit[14]=[17 13] assgined to cell=(17, 8), wts={'explore_wt': 0, 'fuel_wt': np.float32(13.125), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(2.2125), 'energy_ratio': np.float64(0.9833333333333333), 'wt': np.float64(4.157718902199807), 'mdist': np.float64(1.7715610000000008)}
#  unit[15]=[19 19] assgined to cell=(18, 14), wts={'explore_wt': 0, 'fuel_wt': np.float64(2.5322327475098723), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(1.4230555555555555), 'energy_ratio': np.float64(1.8166666666666667), 'wt': np.float64(2.0297883026609793), 'mdist': np.float64(1.9487171000000012)}
# pid=[player_1] game_step=98 sending unit=3 pos=[20  9] to cell=(18, 8)
# pid=[player_1] game_step=98 sending unit=6 pos=[17  7] to cell=(16, 7)
# pid=[player_1] game_step=98 sending unit=7 pos=[18 14] to cell=(17, 14)
# pid=[player_1] game_step=98 sending unit=8 pos=[22 10] to cell=(17, 13)
# pid=[player_1] game_step=98 sending unit=11 pos=[21  9] to cell=(5, 8)
# pid=[player_1] game_step=98 sending unit=13 pos=[21 14] to cell=(16, 14)
# pid=[player_1] game_step=98 sending unit=14 pos=[17 13] to cell=(17, 8)
# pid=[player_1] game_step=98 sending unit=15 pos=[19 19] to cell=(18, 14)
# attack candidates unit=0 pos=[13 11] e=82
# attack candidates unit=2 pos=[21 15] e=107
# attack candidates unit=4 pos=[16 13] e=90
# attack candidates unit=9 pos=[22 12] e=82
# attack candidates unit=10 pos=[15 18] e=104
# attack candidates unit=12 pos=[21 13] e=130
# found attacker unit=0 pos=[13 11] e=82
# found attacker unit=4 pos=[16 13] e=90
# found attacker unit=9 pos=[22 12] e=82
# step=98, unit[[16 13]] sap at [10  7] with damage=-1.0
# step=98, unit[[13 11]] sap at [15  4] with damage=-1.0
# step=98, unit[[22 12]] sap at [15  5] with damage=-1.0
# [debug][step=99] comm_visible.sum() = 192
# step=98 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]
# [debug][step=99] comm_visible.sum() = 252
# step=98 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]
# ============ game step 99 ==========
# [debug][step=99] comm_visible.sum() = 192
# step=98 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]
#  +++ step=99 to-exp-cell-num=60 exp_score=28.327868852459016 has_found_relic=True, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=5
#  unit[0]=[9 3] assgined to cell=(9, 5), wts={'explore_wt': 0, 'fuel_wt': np.float64(2.5578723051970087), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(4.05), 'energy_ratio': np.float64(1.8), 'wt': np.float64(4.964692265362139), 'mdist': np.float64(1.3310000000000004)}
#  unit[1]=[4 1] assgined to cell=(10, 6), wts={'explore_wt': 0, 'fuel_wt': np.float64(3.324564572448146), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.675), 'energy_ratio': np.float64(1.6333333333333333), 'wt': np.float64(2.230376983335595), 'mdist': np.float64(3.138428376721003)}
#  unit[2]=[10  2] assgined to cell=(10, 2), wts={'explore_wt': 0, 'fuel_wt': np.float32(1.5), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': 0, 'energy_ratio': np.float64(0.6), 'wt': np.float64(28.636463636363633), 'mdist': np.float64(1.1)}
#  unit[3]=[11  1] assgined to cell=(11, 1), wts={'explore_wt': 0, 'fuel_wt': np.int16(-1), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': 0, 'energy_ratio': np.float64(0.7333333333333333), 'wt': np.float64(26.36373636363636), 'mdist': np.float64(1.1)}
#  unit[4]=[14  3] assgined to cell=(15, 6), wts={'explore_wt': 0, 'fuel_wt': np.float64(6.1552248800534315), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(4.725), 'energy_ratio': np.float64(2.1), 'wt': np.float64(6.755863627703912), 'mdist': np.float64(1.6105100000000006)}
#  unit[6]=[2 0] assgined to cell=(9, 0), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.6), 'energy_ratio': np.float64(1.6), 'wt': np.float64(1.6795265687550391), 'mdist': np.float64(2.1435888100000016)}
#  unit[7]=[7 1] assgined to cell=(7, 1), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(2.0833333333333335), 'wt': np.float64(27.27282727272727), 'mdist': np.float64(1.1)}
#  unit[8]=[8 2] assgined to cell=(8, 2), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(2.0105555555555554), 'energy_ratio': np.float64(2.566666666666667), 'wt': np.float64(29.10060505050505), 'mdist': np.float64(1.1)}
#  unit[9]=[9 4] assgined to cell=(9, 4), wts={'explore_wt': 0, 'fuel_wt': np.float64(1.7741746202370487), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(4.0874999999999995), 'energy_ratio': np.float64(1.8166666666666667), 'wt': np.float64(5.328895109306407), 'mdist': np.float64(1.1)}
#  unit[10]=[14  2] assgined to cell=(10, 7), wts={'explore_wt': 0, 'fuel_wt': np.float64(9.893528380186051), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(2.5125), 'energy_ratio': np.float64(1.1166666666666667), 'wt': np.float64(4.783160990453051), 'mdist': np.float64(2.5937424601000023)}
#  unit[11]=[5 1] assgined to cell=(9, 1), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.4728014195666929), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(4.05), 'energy_ratio': np.float64(1.8), 'wt': np.float64(2.808403841371175), 'mdist': np.float64(1.6105100000000006)}
#  unit[12]=[7 4] assgined to cell=(9, 6), wts={'explore_wt': 0, 'fuel_wt': np.float64(3.0975271010016723), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.7125000000000004), 'energy_ratio': np.float64(1.65), 'wt': np.float64(4.228591037622659), 'mdist': np.float64(1.6105100000000006)}
#  unit[13]=[9 3] assgined to cell=(9, 3), wts={'explore_wt': 0, 'fuel_wt': np.float64(1.6684042885024013), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(4.05), 'energy_ratio': np.float64(1.8), 'wt': np.float64(5.198649353184001), 'mdist': np.float64(1.1)}
#  unit[14]=[6 2] assgined to cell=(9, 2), wts={'explore_wt': 0, 'fuel_wt': np.float64(1.2456155996891913), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.675), 'energy_ratio': np.float64(1.6333333333333333), 'wt': np.float64(3.3609466632669833), 'mdist': np.float64(1.4641000000000004)}
#  unit[15]=[15  5] assgined to cell=(15, 5), wts={'explore_wt': 0, 'fuel_wt': np.float64(5.000095800703387), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(5.7749999999999995), 'energy_ratio': np.float64(2.566666666666667), 'wt': np.float64(9.795641637003078), 'mdist': np.float64(1.1)}
# pid=[player_0] game_step=99 sending unit=0 pos=[9 3] to cell=(9, 5)
# pid=[player_0] game_step=99 sending unit=1 pos=[4 1] to cell=(10, 6)
# pid=[player_0] game_step=99 sending unit=4 pos=[14  3] to cell=(15, 6)
# pid=[player_0] game_step=99 sending unit=6 pos=[2 0] to cell=(9, 0)
# pid=[player_0] game_step=99 sending unit=10 pos=[14  2] to cell=(10, 7)
# pid=[player_0] game_step=99 sending unit=11 pos=[5 1] to cell=(9, 1)
# pid=[player_0] game_step=99 sending unit=12 pos=[7 4] to cell=(9, 6)
# pid=[player_0] game_step=99 sending unit=14 pos=[6 2] to cell=(9, 2)
# attack candidates unit=7 pos=[7 1] e=125
# attack candidates unit=8 pos=[8 2] e=154
# attack candidates unit=9 pos=[9 4] e=109
# attack candidates unit=13 pos=[9 3] e=108
# attack candidates unit=15 pos=[15  5] e=154
# found attacker unit=8 pos=[8 2] e=154
# found attacker unit=9 pos=[9 4] e=109
# found attacker unit=13 pos=[9 3] e=108
# found attacker unit=15 pos=[15  5] e=154
# step=99, unit[[15  5]] sap at [19  9] with damage=57.75
# step=99, unit[[9 4]] sap at [13 11] with damage=57.75
# step=99, unit[[9 3]] sap at [16  7] with damage=57.75
# step=99, unit[[8 2]] sap saved
# ============ game step 99 ==========
# [debug][step=99] comm_visible.sum() = 252
# step=98 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]
#  +++ step=99 to-exp-cell-num=60 exp_score=28.327868852459016 has_found_relic=True, last_match_found_relic=True
# >>>>>>>>>>>>>>> nebula_energy_reduction=5
#  unit[0]=[13 11] assgined to cell=(13, 11), wts={'explore_wt': 0, 'fuel_wt': np.float32(13.416667), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0, 'energy_ratio': np.float64(0.016666666666666666), 'wt': np.float64(7.697069985961912), 'mdist': np.float64(1.1)}
#  unit[2]=[21 15] assgined to cell=(21, 15), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.8166666666666667), 'wt': np.float64(27.27282727272727), 'mdist': np.float64(1.1)}
#  unit[3]=[19  9] assgined to cell=(17, 8), wts={'explore_wt': 0, 'fuel_wt': np.float64(7.276321196040084), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.675), 'energy_ratio': np.float64(1.6333333333333333), 'wt': np.float64(2.979999730920074), 'mdist': np.float64(1.4641000000000004)}
#  unit[4]=[16 13] assgined to cell=(16, 13), wts={'explore_wt': 0, 'fuel_wt': np.float32(10.25), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.6919444444444445), 'energy_ratio': np.float64(0.8833333333333333), 'wt': np.float64(5.447322222222223), 'mdist': np.float64(1.1)}
#  unit[5]=[22 16] assgined to cell=(22, 16), wts={'explore_wt': 0, 'fuel_wt': np.int16(0), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': 0, 'energy_ratio': np.float64(0.0), 'wt': np.float64(27.27282727272727), 'mdist': np.float64(1.1)}
#  unit[6]=[16  7] assgined to cell=(16, 7), wts={'explore_wt': 0, 'fuel_wt': np.float32(15.666666), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0, 'energy_ratio': np.float64(0.65), 'wt': np.float64(9.742523664439807), 'mdist': np.float64(1.1)}
#  unit[7]=[17 14] assgined to cell=(17, 14), wts={'explore_wt': 0, 'fuel_wt': np.float64(3.6121492018127768), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.5333333333333334), 'wt': np.float64(3.2838720016479788), 'mdist': np.float64(1.1)}
#  unit[8]=[22 11] assgined to cell=(21, 12), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.4124999999999996), 'energy_ratio': np.float64(1.5166666666666666), 'wt': np.float64(2.5639617580766334), 'mdist': np.float64(1.3310000000000004)}
#  unit[9]=[22 12] assgined to cell=(22, 12), wts={'explore_wt': 0, 'fuel_wt': np.int16(-1), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': 0, 'energy_ratio': np.float64(0.6333333333333333), 'wt': np.float64(26.36373636363636), 'mdist': np.float64(1.1)}
#  unit[10]=[15 18] assgined to cell=(15, 18), wts={'explore_wt': 0, 'fuel_wt': np.float64(2.9019623440373743), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.85), 'wt': np.float64(2.638247585488522), 'mdist': np.float64(1.1)}
#  unit[11]=[20  9] assgined to cell=(18, 8), wts={'explore_wt': 0, 'fuel_wt': np.float64(5.812011699419676), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.75), 'energy_ratio': np.float64(1.6666666666666667), 'wt': np.float64(2.0310826510618627), 'mdist': np.float64(1.4641000000000004)}
#  unit[12]=[21 13] assgined to cell=(21, 13), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.5012795459378999), 'relic_nb_wt': np.float64(0.0), 'on_relic_wt': np.float64(30.0), 'sap_wt': np.float64(1.736388888888889), 'energy_ratio': np.float64(2.216666666666667), 'wt': np.float64(29.307071304387986), 'mdist': np.float64(1.1)}
#  unit[13]=[20 14] assgined to cell=(20, 12), wts={'explore_wt': 0, 'fuel_wt': np.float64(0.0), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(3.9375000000000004), 'energy_ratio': np.float64(1.75), 'wt': np.float64(2.958402028549962), 'mdist': np.float64(1.3310000000000004)}
#  unit[14]=[18 13] assgined to cell=(18, 14), wts={'explore_wt': 0, 'fuel_wt': np.float64(6.313383170631203), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.0333333333333334), 'wt': np.float64(5.217772041843968), 'mdist': np.float64(1.2100000000000002)}
#  unit[15]=[19 18] assgined to cell=(16, 18), wts={'explore_wt': 0, 'fuel_wt': np.float64(2.1988994936493986), 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': np.float64(0.0), 'energy_ratio': np.float64(1.8166666666666667), 'wt': np.float64(1.5019779411579797), 'mdist': np.float64(1.4641000000000004)}
# pid=[player_1] game_step=99 sending unit=3 pos=[19  9] to cell=(17, 8)
# pid=[player_1] game_step=99 sending unit=8 pos=[22 11] to cell=(21, 12)
# pid=[player_1] game_step=99 sending unit=11 pos=[20  9] to cell=(18, 8)
# pid=[player_1] game_step=99 sending unit=13 pos=[20 14] to cell=(20, 12)
# pid=[player_1] game_step=99 sending unit=14 pos=[18 13] to cell=(18, 14)
# pid=[player_1] game_step=99 sending unit=15 pos=[19 18] to cell=(16, 18)
# attack candidates unit=2 pos=[21 15] e=109
# attack candidates unit=4 pos=[16 13] e=53
# attack candidates unit=7 pos=[17 14] e=92
# attack candidates unit=10 pos=[15 18] e=111
# attack candidates unit=12 pos=[21 13] e=133
# found attacker unit=4 pos=[16 13] e=53
# found attacker unit=12 pos=[21 13] e=133
# step=99, unit[[21 13]] sap at [15  6] with damage=17.36388888888889
# step=99, unit[[16 13]] sap at [14  6] with damage=17.36388888888889
# [debug][step=100] comm_visible.sum() = 174
# step=99 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]
# [debug][step=100] comm_visible.sum() = 255
# step=99 (after update), energy field found=True, node=[19  2], candidates=[array([19,  2])]
# --> using energy node at [19  2]

# %%
PLAYER_ID = 1
ob = obs[PLAYER_ID]
print(ob['game_step'][0][0][0] * 505, ob['match_step'][0][0][0] * 100)

units_loc = ob['units_loc_t0']
units_energy = ob['units_energy_t0']
enemy_loc = ob['enemy_loc_t0']

nu = env.mms[PLAYER_ID].past_obs[0]['units_mask'][0].sum()
print(f'number of units: {nu}')

plot_imgs([('cell_energy', ob['_a_cell_energy']), ('cell types', ob['_a_cell_type']), ('team_point_prob', ob['_a_team_point_prob']),
           ('_b_cell_energy', ob['_b_cell_energy']), ('_b_cell_type', ob['_b_cell_type']), ('_b_team_point_prob', ob['_b_team_point_prob']),    
            ('is_relic_node', ob['_a_is_relic_node']), ('_b_is_relic_node', ob['_b_is_relic_node']),  
           ('units_loc', units_loc > 0),  ('_a_is_relic_neighbour', ob['_a_is_relic_neighbour']), ('enemy_loc', enemy_loc > 0) 
           ])
# Out:
# 100.0 100.0
# number of units: 2

# %%
env.raw_obs['player_1']['units']['position'][1]
# Out:
# array([[13, 11],
#        [23, 23],
#        [21, 15],
#        [19,  8],
#        [16, 13],
#        [22, 16],
#        [16,  7],
#        [17, 14],
#        [22, 12],
#        [22, 12],
#        [15, 18],
#        [19,  9],
#        [21, 13],
#        [20, 13],
#        [18, 14],
#        [18, 18]], dtype=int16)

# %%
env.raw_obs['player_1']['units']['energy'][1]
# Out:
# array([-44, 100, 111,  91,  16,   0,   4,  98,  90,  39, 118,  58,  91,
#        106,  66, 110], dtype=int16)

# %%
env.raw_obs['player_1']['units_mask'][1]
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
a1.mm.get_unit_positions(env.raw_obs['player_1'], a1.mm.player_id)
# Out:
# array([[23, 23],
#        [21, 15],
#        [19,  8],
#        [16, 13],
#        [22, 16],
#        [16,  7],
#        [17, 14],
#        [22, 12],
#        [22, 12],
#        [15, 18],
#        [19,  9],
#        [21, 13],
#        [20, 13],
#        [18, 14],
#        [18, 18]], dtype=int16)

# %%
ob = env.raw_obs['player_1']
pid = 1
drop_died = True

unit_masks = ob['units_mask'][pid]
unit_energy = ob['units']['energy'][pid]

mask = unit_masks
if drop_died:
    mask &= (unit_energy >= 0)

unit_positions = ob['units']['position'][pid][mask]

# %%
unit_masks
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
unit_energy >= 0
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
(unit_energy >= 0) & (unit_masks)
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
len(env.mms[1].team_point_probs)
# Out:
# 100

# %%
from ecobangbang.env.mapmanager import SAVE_ALL_STEPS_TP_PROB

SAVE_ALL_STEPS_TP_PROB
# Out:
# True

# %%
def extract_all(pos):
    return [(step, probs[pos[0]][pos[1]])
            for step, probs in enumerate(env.mms[1].team_point_probs)]


pd.DataFrame(extract_all((21, 13)), columns=['step', 'prob']).set_index('step').plot()
# Out:
# <Axes: xlabel='step'>

# %%
pd.DataFrame(extract_all((22, 16)), columns=['step', 'prob']).set_index('step').plot()
# Out:
# <Axes: xlabel='step'>

# %%
pd.DataFrame(extract_all((21, 15)), columns=['step', 'prob']).set_index('step').plot()
# Out:
# <Axes: xlabel='step'>

# %%
pd.DataFrame(extract_all((22, 12)), columns=['step', 'prob']).set_index('step').plot()
# Out:
# <Axes: xlabel='step'>

# %%
PLAYER_ID = 1
ob = obs[PLAYER_ID]
print(ob['game_step'][0][0][0] * 505, ob['match_step'][0][0][0] * 100)

units_loc = ob['units_loc_t0']
units_energy = ob['units_energy_t0']
enemy_loc = ob['enemy_loc_t0']

nu = env.mms[PLAYER_ID].past_obs[0]['units_mask'][0].sum()
print(f'number of units: {nu}')

plot_imgs([('cell_energy', ob['_a_cell_energy']), ('cell types', ob['_a_cell_type']), ('team_point_prob', ob['_a_team_point_prob']),
           ('_b_cell_energy', ob['_b_cell_energy']), ('_b_cell_type', ob['_b_cell_type']), ('_b_team_point_prob', ob['_b_team_point_prob']),    
            ('is_relic_node', ob['_a_is_relic_node']), ('_b_is_relic_node', ob['_b_is_relic_node']),  
           ('units_loc', units_loc > 0),  ('_a_is_relic_neighbour', ob['_a_is_relic_neighbour']), ('enemy_loc', enemy_loc > 0) 
           ])
# Out:
# 100.0 100.0
# number of units: 2

# %%
env.raw_obs['player_1']['units']['position'][1]
# Out:
# array([[13, 11],
#        [23, 23],
#        [21, 15],
#        [19,  8],
#        [16, 13],
#        [22, 16],
#        [16,  7],
#        [17, 14],
#        [22, 12],
#        [22, 12],
#        [15, 18],
#        [19,  9],
#        [21, 13],
#        [20, 13],
#        [18, 14],
#        [18, 18]], dtype=int16)

# %%
env.raw_obs['player_1']['units']['energy'][1]
# Out:
# array([-44, 100, 111,  91,  16,   0,   4,  98,  90,  39, 118,  58,  91,
#        106,  66, 110], dtype=int16)

# %%
env.raw_obs['player_1']['units_mask'][1]
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
from scipy.ndimage import maximum_filter, minimum_filter
from ecobangbang.env.mapmanager import *

energy_node = (4, 15)
mp = np.zeros(MAP_SHAPE2, dtype=bool)

mp[energy_node[0]][energy_node[1]] = True
mp = maximum_filter(mp, size=MAX_ENERGY_NODE_DRIFT_MAGNITUDE*2+1)
# mp[energy_node[0]][energy_node[1]] = False

upper = generate_manhattan_mask((MAP_WIDTH, MAP_HEIGHT), (0, 0),
                                MAP_WIDTH-1)
mp[~(upper)] = False

np.argwhere(mp)
len(np.argwhere(mp))
# Out:
# 89

# %% [markdown]
# # Debug enery field

# %%
sensor_mask = env.raw_obs['player_1']['sensor_mask']
map_energy = env.raw_obs['player_1']['map_features']['energy']
filtered_energy_field = map_energy[sensor_mask]
fig, axes = plt.subplots(1, 2, figsize=(15, 5)) 

axes[0].imshow(map_energy.T)
axes[1].imshow(sensor_mask.T)
filtered_energy_field
# Out:
# array([ 5,  2, -1, -5, -6, -4,  2,  8,  9,  8,  1, -4, -6, -4,  2,  8,  9,
#         8,  3, -3, -6, -4,  3,  9, -4,  2, -1, -2, -4, -4, -3,  1,  6,  9,
#         8,  3, -4, -6, -2,  5,  9, -2, -5, -1,  6,  1,  1, -1, -3, -6, -5,
#        -1,  5,  9,  8,  1, -5, -5,  1,  7,  7,  1, -4, -3,  3,  4,  5,  5,
#         3, -1, -5, -6, -1,  6,  9,  6, -1, -5, -2,  5,  8,  4, -2, -4,  1,
#         4,  6,  8,  9,  6,  0, -5, -5,  1,  7,  8,  2, -4, -4,  2,  7,  6,
#         0, -4, -1,  1,  1,  4,  8, 10,  6, -1, -6, -3,  4,  8,  5, -1, -4,
#         0,  6,  6,  2, -3, -2, -2, -4, -3,  2,  8,  9,  3, -3, -4,  1,  6,
#         6,  1, -3, -1,  4,  6,  3, -2, -2, -1, -4, -6, -3,  4,  8,  5, -1,
#        -4,  0,  5,  6,  2, -2, -1,  3,  6,  3, -1, -2,  3,  0, -4, -4,  1,
#         6,  5,  1, -2, -1,  4,  5,  2, -1, -1,  2,  5,  3, -1, -2,  1,  5,
#         3, -1, -2,  1,  4,  4,  1, -1,  0,  3,  5,  2, -1, -1,  2,  4,  3,
#         0, -1,  1,  1,  2,  1,  1,  3,  3,  1,  0,  0,  3,  4,  2,  0,  0,
#         2,  4,  3,  0, -1,  1,  2,  3,  2,  2,  2,  2,  1,  1,  1,  2,  3,
#         2,  0,  0,  2,  3,  2,  0,  0,  2,  1,  2,  1,  2,  2,  1,  2,  2,
#         2,  1,  1,  1,  2,  3,  2,  0,  0,  2], dtype=int16)

# %%
m, f = env.mms[1].energy_node_estimator.is_energy_filed_match((1, 15), filtered_energy_field, sensor_mask)
f = np.asarray(f).copy()
f[~sensor_mask] = -1
plt.imshow(f.T)
m
# Out:
# Array(False, dtype=bool)

# %%
f[sensor_mask]
# Out:
# array([ 6,  2,  0,  1,  2, -1, -5, -6, -2,  4,  5,  6,  3, -2, -5, -3,  0,
#         5,  9,  8,  3, -1,  1,  5,  2,  0,  2,  1,  2,  2,  0, -3, -4,  0,
#         6,  9,  6,  2,  2,  5,  8,  7,  3, -1, -4,  2,  1,  3,  5,  3, -2,
#        -6, -5,  0,  5,  5,  1, -1, -1,  2,  4,  4,  2,  0,  0,  0,  0,  3,
#         7,  7,  3, -4, -6, -4,  0,  2,  0, -4, -6, -5, -3, -1,  1,  3,  5,
#        -2, -3, -1,  5,  9,  8,  3, -2, -3, -1,  2,  2, -1, -4, -5, -5, -3,
#         0,  3,  5,  0, -4, -5,  0,  6,  9,  7,  3,  0,  1,  4,  6,  6,  4,
#         2,  0,  0,  1,  2,  1,  4, -1, -6, -5,  0,  5,  7,  5,  2,  1,  3,
#         6,  9,  9,  8,  6,  4,  3,  1, -1,  8,  4, -2, -6, -5, -1,  3,  3,
#         2, -1, -1,  1,  4,  6,  7,  6,  5,  3,  1,  0,  9,  9,  4, -1, -4,
#        -3,  0,  1,  1, -2, -4, -5, -4, -2,  0,  1,  1,  1,  2,  2,  4,  4,
#         9,  8,  4,  0, -2,  0,  2,  2,  1, -2, -4, -6, -6, -5, -4, -2,  0,
#         2,  3,  5,  3,  7,  7,  4,  2,  1,  3,  5,  6,  5,  3,  0, -1, -2,
#        -2, -1,  0,  1,  2,  2, -3,  2,  5,  5,  3,  1,  2,  4,  7,  9,  9,
#         8,  7,  5,  4,  3,  2,  2,  1, -1, -5, -2,  2,  0, -1, -1,  1,  4,
#         7,  8,  8,  8,  7,  5,  3,  2,  0, -1], dtype=int16)

# %%
m, f = env.mms[1].energy_node_estimator.is_energy_filed_match((4, 15), filtered_energy_field, sensor_mask)
f = np.asarray(f).copy()
f[~sensor_mask] = -1
plt.imshow(f.T)
m
# Out:
# Array(False, dtype=bool)

# %%
f[sensor_mask]
# Out:
# array([ 2,  2,  0, -1,  1,  6,  9,  8,  3,  4, -3, -3,  2,  8,  9,  6,  3,
#        -3, -6, -3,  2,  6,  5,  1, -6, -3,  3,  1, -2, -1,  4,  8,  7,  2,
#        -4, -6, -3,  1,  2,  1, -2, -3,  0,  4,  8,  5,  3, -2, -4,  0,  6,
#        10,  7,  2, -3, -3, -1,  2,  3,  4,  4,  5,  8,  9,  9,  7,  6,  0,
#        -5, -5,  1,  7, 10,  7,  3,  0,  0,  3,  5,  7,  9,  9,  9,  7,  4,
#         6,  8,  5, -2, -6, -5,  1,  6,  8,  6,  4,  2,  2,  3,  4,  5,  4,
#         2, -1, -4,  2,  8,  9,  4, -2, -6, -5,  0,  4,  5,  4,  2,  0, -1,
#        -2, -3, -4, -5, -6, -6, -3,  4,  9,  9,  4, -2, -5, -4, -1,  1,  2,
#         1,  0, -2, -4, -5, -5, -4, -3,  1, -6, -2,  5,  9,  9,  5,  0, -2,
#        -2,  0,  1,  2,  2,  2,  1,  1,  2,  4,  6,  8, -5, -6, -2,  4,  8,
#         8,  6,  3,  1,  1,  2,  3,  5,  6,  7,  8,  9,  9, 10,  9,  7,  1,
#        -5, -6, -3,  2,  6,  7,  5,  3,  2,  2,  3,  4,  5,  6,  7,  7,  6,
#         4,  1, -2,  1, -4, -5, -3,  0,  3,  4,  4,  2,  1,  0,  0,  0,  0,
#         0, -1, -2, -4, -6, -6,  7,  3, -2, -4, -3, -1,  1,  2,  2,  1, -1,
#        -2, -3, -4, -5, -5, -6, -5, -4, -2,  9,  8, -1, -1,  0,  1,  2,  2,
#         2,  1,  0, -1, -1, -1,  0,  2,  4,  7], dtype=int16)

# %% [markdown]
# # Debug score assigment

# %%
from ecobangbang.agent import *

# %%
SUBMIT_AGENT = False

# %%
self = a1

# %%
mm.team_point_mass[21][13]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mm.team_point_mass[21][13]
#
# NameError: name 'mm' is not defined

# %%
mm.team_point_mass[22][12]

# %%
mm = self.mm
is_explore_step = (mm.match_step <= 50 and mm.game_step < 303)

match_observed = mm.match_observed + anti_diag_sym(mm.match_observed)
energy_threshold = 60 + mm.match_step

# TODO: test drop it
if mm.match_step >= 70:
  energy_threshold = 60

has_found_relic = mm.has_found_relic_in_match()
n = (MAP_WIDTH * MAP_HEIGHT)
n_explore = n - match_observed.sum()
expore_score = n * EXPLORE_CELL_SCORE / (n_explore + 1)
print(
    f' +++ step={mm.game_step} to-exp-cell-num={n_explore} exp_score={expore_score} has_found_relic={has_found_relic}, last_match_found_relic={mm.last_match_found_relic}',
    file=sys.stderr)

def get_explore_weight(upos, energy, cpos):
  if mm.game_step >= (3 * MAX_MATCH_STEPS):
    return 0

  if not mm.last_match_found_relic:
    return 0

  if has_found_relic:
    return 0

  if match_observed[cpos[0]][cpos[1]]:
    return 0

  return min(expore_score, MAX_EXPLORE_SCORE)

energy_map = mm.cell_energy.copy()
energy_map[mm.cell_energy != CELL_UNKONWN] -= mm.unit_move_cost
energy_map[mm.cell_type == CELL_NEBULA] -= mm.nebula_energy_reduction
if not SUBMIT_AGENT:
  print(
      f'>>>>>>>>>>>>>>> nebula_energy_reduction={mm.nebula_energy_reduction}',
      file=sys.stderr)

fire_zone = self.gen_fire_zone()

player_init_pos = get_player_init_pos(mm.player_id)
d1 = generate_manhattan_dist(MAP_SHAPE2,
                             player_init_pos).astype(np.float32)
# d1[d1 > MAP_WIDTH] = MAP_WIDTH
d1 /= MAP_WIDTH

def get_fuel_energy(upos, energy, cpos):
  e = fuel = energy_map[cpos[0]][cpos[1]]
  fuel = right_tailed_exp(energy, fuel, energy_threshold)

  # Boost more net energy position without energy thresholding
  if e > 0 and fire_zone[cpos[0]][cpos[1]]:
    fuel += (e * d1[cpos[0]][cpos[1]])

  return fuel

enemy_sap_range = self.get_enemy_sap_range()

def get_open_relic_nb(upos, energy, cpos):
  """First visit on relic neighbour"""
  if not mm.is_relic_neighbour[cpos[0]][cpos[1]]:
    return 0

  # if not mm.match_visited[cpos[0]][cpos[1]]:
  # return RELIC_NB_SCORE

  p = mm.team_point_mass[cpos[0]][cpos[1]]
  if p < MIN_OPEN_RELIC_NB_PROB:
    return 0

  v = RELIC_NB_SCORE
  # Lower relic nb on enemy side
  if on_enemy_side(cpos, mm.player_id):
    # v = mm.unit_sap_cost / 10 * p
    v = mm.unit_sap_cost / 10

  # If enemy may sap it, lower its weight
  if enemy_sap_range[cpos[0]][cpos[1]]:
    v = mm.unit_sap_cost / 10 * 0.5

  last_visited_step = mm.last_visited_step[cpos[0]][cpos[1]]
  t = mm.game_step - last_visited_step
  alpha = np.log(t + 1) / LOG3
  w = min(alpha, 1) * v

  # cpos_nb_mask = gen_sap_range(cpos, self.mm.unit_sap_range)
  # if (mm.enemy_max_energy[cpos_nb_mask] > energy).sum() > 0:
  # w = -1
  return w

init_pos = get_player_init_pos(mm.enemy_id)
enemy_half = generate_manhattan_mask(MAP_SHAPE2,
                                     init_pos,
                                     range_limit=MAP_WIDTH - 1)
blind_shot_targets = ((~mm.visible) &
                      (mm.team_point_mass > IS_RELIC_CELL_PROB)
                      & enemy_half)
# blind_shot_targets = np.zeros(MAP_SHAPE2, dtype=bool)  # disable blind shot
self.blind_shot_targets = blind_shot_targets

def stay_on_relic(upos, energy, cpos):
  # If the relic node has been occupied by unit but not this one, lower its score
  if (mm.unit_positions[cpos[0]][cpos[1]] and not pos_equal(upos, cpos)):
    print(f" relic node has been occupied by unit but not this one")
    return 0

  # # Relic unit do not change relic position
  # p_unit = mm.team_point_mass[upos[0]][upos[1]]
  # if (p_unit > IS_RELIC_CELL_PROB and not pos_equal(upos, cpos)):
  # return 0

  # Will score only for relic p > 0.8
  v = RELIC_SCORE
  p = mm.team_point_mass[cpos[0]][cpos[1]]

  # Do not goto enemy side if energy below threshold
  if on_enemy_side(cpos, mm.player_id):
    v = mm.unit_sap_cost / 10

  # If enemy may sap it, lower its weight
  if not pos_equal(cpos, upos) and enemy_sap_range[cpos[0]][cpos[1]]:
    v = mm.unit_sap_cost / 10 * 0.5

  w = 0
  if p > IS_RELIC_CELL_PROB:
    w += v * p

  return w

hit_factor = 10
enemy_hit_map = self.get_sap_hit_map(hit_factor)
enemy_hit_map[
    blind_shot_targets] += mm.unit_sap_cost  # roughly adding 3 points
self.enemy_hit_map = enemy_hit_map

def get_sap_enemy_score(upos, energy, cpos):
  """Max sap damage that could be hit from the `cpos`."""
  if not can_attack(energy, mm):
    return 0

  # Do not attack from negtive energy position
  # fuel = energy_map[cpos[0]][cpos[1]]
  # if fuel <= 0:
  # return 0

  sap_range = gen_sap_range(cpos, self.mm.unit_sap_range)

  h = enemy_hit_map[sap_range].max()
  h /= hit_factor

  # Boost unit with extra energy for SAP
  h *= min(energy / BOOST_SAP_ENERGY_THRESHOOD, 1)

  # sap if energy is large (and unit not on relic)
  # if self.mm.team_point_mass[pos[0]][pos[1]] < 0.6:
  # h *= max((energy / energy_threshold), 1)
  return h

score_debug = {}

def get_unit_cell_wt(upos, energy, cpos, unit_cost_map):
  if cant_move_to(upos, cpos, mm):
    return -9999

  if energy < unit_cost_map[cpos[0]][cpos[1]]:
    # if not SUBMIT_AGENT:
    # print(f'game_step={mm.game_step}: skip due to inf at {cpos}',
    # file=sys.stderr)
    return -9999

  # Do not target cell with enemy energy > unit energy
  if energy < mm.enemy_max_energy[cpos[0]][cpos[1]]:
    return -9999

  # mdist = manhatten_distance(upos, cpos) + 7
  mdist = dd(manhatten_distance(upos, cpos) + 1)
  wt = 0.0001

  energy_ratio = energy / energy_threshold

  expore_wt = get_explore_weight(upos, energy, cpos)

  fuel_wt = get_fuel_energy(upos, energy, cpos)

  relic_nb_wt = get_open_relic_nb(upos, energy, cpos)

  on_relic_wt = stay_on_relic(upos, energy, cpos)

  sap_wt = get_sap_enemy_score(upos, energy, cpos)

  # If enemy hit me at relic position, skip them?
  cpos_nb_mask = gen_sap_range(cpos, self.mm.unit_sap_range + 1)
  # any_enemy_nearby = mm.enemy_position_mask_can_negtive[cpos_nb_mask].sum(
  # ) > 0
  # if not any_enemy_nearby and energy_lost_mask[cpos[0]][cpos[1]]:
  # on_relic_wt *= 0.2
  # relic_nb_wt *= 0.2

  wt += (expore_wt + fuel_wt + relic_nb_wt + on_relic_wt + sap_wt) / mdist

  is_relic_nb = mm.is_relic_neighbour[cpos[0]][cpos[1]]
  # has enemy nearby, dangerous, go away
  has_enemy_nearby = (mm.enemy_max_energy[cpos_nb_mask] > energy).sum() > 0
  if (has_enemy_nearby
      and (not is_relic_nb or on_enemy_side(cpos, mm.player_id))):
    wt -= self.mm.unit_sap_cost / 10
    print(f"has enemy nearby, dangerous, go away: {self.mm.unit_sap_cost / 10}")

  score_debug[(tuple(upos), tuple(cpos))] = {
      'explore_wt': expore_wt,
      'fuel_wt': fuel_wt,
      'relic_nb_wt': relic_nb_wt,
      'on_relic_wt': on_relic_wt,
      'sap_wt': sap_wt,
      'energy_ratio': energy_ratio,
      'wt': wt,
      'mdist': mdist,
  }

  # if USE_RANDOM:
  # wt += np.random.rand() / 1000
  return wt

# %%
self.mm.game_step

# %%
upos = (21, 13)
unit_cost_map = self.compute_energy_cost_map(upos, asteriod_cost=75)

energy = 106
get_unit_cell_wt(upos, energy, upos, unit_cost_map)

# %%
cpos = (20, 12)
get_unit_cell_wt(upos, energy, cpos, unit_cost_map)

# %%
score_debug

# %%
mm.team_point_mass[21][16]

# %%
mm.game_step

# %%
energy_lost_mask[]

# %%
mm.sap_dropoff_factor_estimator.unit_energy_lost_step[21][16]

# %%
from ecobangbang.agent import *

# %%
hit_map = np.zeros((MAP_WIDTH, MAP_HEIGHT), dtype=float)

for i in range(MAX_UNIT_NUM):
  mask, pos, energy = self.mm.get_unit_info(self.mm.enemy_id, i, t=0)
  if not mask:
    continue

  if self.mm.enemy_positions[pos[0]][pos[1]]:
    p = self.mm.team_point_mass[pos[0]][pos[1]]
    hit_map[pos[0]][pos[1]] += (RELIC_SCORE * (p**2))

  for d in [1, 0]:
    x0 = max(0, (pos[0] - d))
    x1 = min(MAP_WIDTH, (pos[0] + d + 1))
    y0 = max(0, (pos[1] - d))
    y1 = min(MAP_HEIGHT, (pos[1] + d + 1))

    h = self.mm.unit_sap_cost
    if d == 1:
      h *= self.mm.unit_sap_dropoff_factor
    hit_map[x0:x1, y0:y1] += h

cpos = upos
sap_range = gen_sap_range(cpos, self.mm.unit_sap_range)

# %%
plot_imgs([('enemy_hit_map', enemy_hit_map), ('mm.enemy_positions', mm.enemy_positions), ('hit_map', hit_map),
           ('sap_range', sap_range), ])

# %%
print("============ game step 468 ========== \nunit[[9 3]] and cell ((1, 0)) wt={'explore_wt': 0, 'fuel_wt': -3.726653172078671e-05, 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0.0, 'energy_ratio': 2.25, 'wt': 8.81257345245768e-05, 'mdist': 3.138428376721003}\nunit[[9 3]] and cell ((2, 0)) wt={'explore_wt': 0, 'fuel_wt': -2.9813225376629368e-05, 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0.0, 'energy_ratio': 2.25, 'wt': 8.955064638162758e-05, 'mdist': 2.8531167061100025}\nunit[[9 3]] and cell ((3, 0)) wt={'explore_wt': 0, 'fuel_wt': -1.8633265860393355e-05, 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0.0, 'energy_ratio': 2.25, 'wt': 9.281606938736897e-05, 'mdist': 2.5937424601000023}\nunit[[9 3]] and cell ((4, 0)) wt={'explore_wt': 0, 'fuel_wt': -7.453306344157342e-06, 'relic_nb_wt': 0, 'on_relic_wt': 0, 'sap_wt': 0.0, 'energy_ratio': 2.25, 'wt': 9.683907053044235e-05, 'mdist': 2.357947691000002}\nunit[[9 3]] and cell ((5, 0)) wt={'explore_wt': 0, 'fuel_wt': 3.726653172078671e-06, 'relic_nb_wt': 0, 'on_relic_wt': ")

# %% [markdown]
# # Map Tile Shift Estimation

# %%
partial = ob['_a_cell_type'][0, :, :]

# %%
cell_map = ob['_b_cell_type'][0, :, :]
plt.imshow(cell_map.T)

# %%
def shift_map(mp, n):
    mp = np.roll(mp, shift=-n, axis=0)  # Shift Up
    mp = np.roll(mp, shift=n, axis=1)  # Shift right
    return mp


fig, axes = plt.subplots(1, 2, figsize=(10, 5)) 

axes[0].imshow(partial.T)
axes[1].imshow(shift_map(partial, -1).T)

# %%
a = cell_map == 2

a.size

# %%
(cell_map[cell_map == 2] != partial[cell_map == 2]).any()

# %%
x = np.array([-0.15, -0.1, -0.05, -0.025, 0.025, 0.05, 0.1, 0.15])

1 / x

# %%
def should_tile_change(steps, nebula_tile_drift_speed):
    return (steps - 1) * abs(nebula_tile_drift_speed) % 1 > steps * abs(nebula_tile_drift_speed) % 1


x = np.linspace(0, 500, 101)


df = pd.DataFrame({
    'x': x,
    'c15': should_tile_change(x, 0.15).astype(int),
    # 'c20': -should_tile_change(x, 0.10).astype(int),
    # 'c05': should_tile_change(x, 0.05).astype(int),
    'c025': -should_tile_change(x, 0.01).astype(int),
})

df.set_index('x').plot()
