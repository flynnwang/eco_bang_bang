# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import json

# %matplotlib inline

# %%
# file_path = "/Users/flynnwang/repo/flynn/eco_bang_bang/agents/tmp/67265373-1.json"
# file_path = "/Users/flynnwang/repo/flynn/eco_bang_bang/agents/tmp/67536105-1.json"
file_path = "/Users/flynnwang/repo/flynn/eco_bang_bang/agents/tmp/67763340-0.json"
# 

with open(file_path) as f:
    j = json.load(f)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
for i, x in enumerate(j):
    stderr = x[0]['stderr']    
    print(i, stderr)
# Out:
# 0  +++ step=0 to-exp-cell-num=576 exp_score=2.9948006932409013 has_found_relic=False, last_match_found_relic=True
#
# 1 [debug][step=1] comm_visible.sum() = 0
# ***** --> found energy node at [14  8]
# step=0 (after update), energy field found=True, node=[14  8], candidates=[array([14,  8])]
# --> using energy node at [14  8]
#  +++ step=1 to-exp-cell-num=534 exp_score=3.229906542056075 has_found_relic=False, last_match_found_relic=True
#
# 2 [debug][step=2] comm_visible.sum() = 18
# ***** --> found energy node at [14  5]
# ----------small reset energy node positions, found? = True
# energy field changed at step = 1
# step=1 (after update), energy field found=True, node=[14  5], candidates=[array([14,  5])]
# --> using energy node at [14  5]
#  +++ step=2 to-exp-cell-num=518 exp_score=3.3294797687861273 has_found_relic=False, last_match_found_relic=True
#
# 3 [debug][step=3] comm_visible.sum() = 26
# ...
